# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Data preparation
data = {
    'area': [2600, 3000, 3200, 3600, 4000],
    'price': [550000, 565000, 610000, 680000, 725000]
}
df = pd.DataFrame(data)
print(df)

# Plot scatter plot of the data
plt.xlabel('Area (sq ft)')
plt.ylabel('Price')
plt.scatter(df.area, df.price, color='red', marker='+')

# Preparing data for training
new_df = df.drop('price', axis='columns')
price = df.price
print(new_df)
print(price)

# Linear regression model
reg = LinearRegression()
reg.fit(new_df, price)

# Print model parameters
print(f"Coefficient: {reg.coef_}")
print(f"Intercept: {reg.intercept_}")

# Predicting prices
areas_to_predict = pd.DataFrame({'area': [5000, 8000, 9000]})
predicted_prices = reg.predict(areas_to_predict)

# Display predictions
for area, price in zip(areas_to_predict['area'], predicted_prices):
    print(f"Predicted price for area {area} sq ft is {price}")

# Plot regression line
plt.plot(df.area, reg.predict(new_df), color='blue', label='Regression Line')
plt.legend()
plt.show()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64
# Coefficient: [135.78767123]
# Intercept: 180616.43835616432
# Predicted price for area 5000 sq ft is 859554.7945205481
# Predicted price for area 8000 sq ft is 1266917.8082191783
# Predicted price for area 9000 sq ft is 1402705.479452055
